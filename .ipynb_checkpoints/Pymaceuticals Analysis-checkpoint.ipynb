# %% [markdown]
# ### Analysis of Pymaceuticals Drugs and their Affects on Mouse Tumors
# Based on the analysis of the data below, we have found that the two drugs that appear to be the safest and provide the best results are Capomulin and Ramicane.  These mice had longer life spans across the span of the study, and they also had smaller tumor sizes at the time of the final timepoint measurement.  More studies should be designed for these two drugs in particular.
#
# While not a direct observation on the drug results, we also saw the correlation between the weight of the mice themselves, and the sizes of the tumors they suffered.  Perhaps more studies should be designed to find definitive results on this idea.
#
# Alarmingly, mice on any drug other than Capomulin and Ramicane performed at around the same level as mice on the Placebo, except for mice on Propriva which lived the shortest in the study on average.

# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="outer")

# Display the data table for preview
merge_df.head(20)
merge_df.tail(20)
merge_df.head(5)
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
mouse_count=merge_df["Mouse ID"].value_counts()
print(f"Current Mouse Count: {len(mouse_count)}")
# Out:
# Current Mouse Count: 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dupsearch=merge_df[["Mouse ID","Timepoint"]]
dupsearch
dupsearch[merge_df.duplicated(keep=False)]
# Out:
#     Mouse ID  Timepoint
# 908     g989          0
# 909     g989          0

# %%
# Optional: Get all the data for the duplicate mouse ID. 
g989_df=merge_df[merge_df["Mouse ID"]=="g989"]
g989_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_merge = merge_df[merge_df['Mouse ID'] != 'g989']
clean_merge
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
#print(len(clean_merge))

new_mouse_count=clean_merge["Mouse ID"].value_counts()
print(f"Cleaned Mouse Count: {len(new_mouse_count)}")
# Out:
# Cleaned Mouse Count: 248

# %% [markdown]
# ## Summary Statistics

# %%
#find drug names; 
clean_merge[["Drug Regimen","Timepoint","Tumor Volume (mm3)"]]
clean_merge["Drug Regimen"].value_counts()

#change Tumor Volume to int32
clean_merge["Tumor Volume (mm3)"].astype("int32").dtypes
# Out:
# dtype('int32')

# %%
# # Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
drug_groups = clean_merge.groupby("Drug Regimen")
#OMG! describe for basic data
summary=drug_groups["Tumor Volume (mm3)"].describe()
summary
# Out:
#               count       mean       std        min        25%        50%  \
# Drug Regimen
# Capomulin     230.0  40.675741  4.994774  23.343598  37.685933  41.557809
# Ceftamin      178.0  52.591172  6.268188  45.000000  47.208427  51.776157
# Infubinol     178.0  52.884795  6.567243  36.321346  47.312353  51.820584
# Ketapril      188.0  55.235638  8.279709  45.000000  48.232987  53.698743
# Naftisol      186.0  54.331565  8.134708  45.000000  47.285874  52.509285
# Placebo       181.0  54.033581  7.821003  45.000000  47.459053  52.288934
# Propriva      148.0  52.320930  6.622085  45.000000  46.894328  50.446266
# Ramicane      228.0  40.216745  4.846308  22.050126  36.674635  40.673236
# Stelasyn      181.0  54.233149  7.710419  45.000000  48.047139  52.431737
# Zoniferol     182.0  53.236507  6.966589  45.000000  47.337876  51.818479
#
#                     75%        max
# Drug Regimen
# Capomulin     45.000000  48.158209
# Ceftamin      56.801438  68.923185
# ...

# %%
#adjust summary table to reflect values you want

###MEDIAN
tumor_vol_med = round(drug_groups["Tumor Volume (mm3)"].median(),2)
###SEM
tumor_sem=round(drug_groups['Tumor Volume (mm3)'].sem(),2)
tumor_var=round(drug_groups["Tumor Volume (mm3)"].var(),2)
#add columns you want
summary["Variance"]=tumor_var
summary["Median"]=tumor_vol_med
# summary["Standard Deviation"]=tumor_std
summary["SEM"]=tumor_sem

summary[["mean","std","Median","Variance","SEM"]]
tumor_by_drug_summary=summary[["mean","Median","Variance","std","SEM"]]
tumor_by_drug_summary=tumor_by_drug_summary.rename(columns={"mean":"Mean", "std":"Standard Deviation"})
tumor_by_drug_summary
# Out:
#                    Mean  Median  Variance  Standard Deviation   SEM
# Drug Regimen
# Capomulin     40.675741   41.56     24.95            4.994774  0.33
# Ceftamin      52.591172   51.78     39.29            6.268188  0.47
# Infubinol     52.884795   51.82     43.13            6.567243  0.49
# Ketapril      55.235638   53.70     68.55            8.279709  0.60
# Naftisol      54.331565   52.51     66.17            8.134708  0.60
# Placebo       54.033581   52.29     61.17            7.821003  0.58
# Propriva      52.320930   50.45     43.85            6.622085  0.54
# Ramicane      40.216745   40.67     23.49            4.846308  0.32
# Stelasyn      54.233149   52.43     59.45            7.710419  0.57
# Zoniferol     53.236507   51.82     48.53            6.966589  0.52

# %%
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
#and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
#use agg resource
drug_groups.agg({"Tumor Volume (mm3)":['mean','median','var', 'std', 'sem']})
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
test_df=clean_merge.groupby(["Drug Regimen"])
test_list=test_df["Timepoint"].count()
# test.max() #12
test_list
#series = index and values
# Out:
# Drug Regimen
# Capomulin    230
# Ceftamin     178
# Infubinol    178
# Ketapril     188
# Naftisol     186
# Placebo      181
# Propriva     148
# Ramicane     228
# Stelasyn     181
# Zoniferol    182
# Name: Timepoint, dtype: int64

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
#df.plot
test_list

drug_graph_pandas=test_list.plot.bar(x=test_list.index, y=test_list.values, title="Lifespan of Mice")

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

#y data is timepoints, x data is drug regimens
drugs=test_df["Drug Regimen"]

plt.bar(test_list.index, test_list.values, color='m', alpha=0.5)
plt.xlabel("Drug Regimen")
plt.ylabel("Timepoints")
plt.title("Lifespan of Mice")
plt.xticks(rotation = 45)
plt.show()

# %%
#gather male/female data.  Does it matter if we count total female/male 
    #comparison data, or should we only use each mouse once?

gender_count=clean_merge.Sex.value_counts()


female_count=958
male_count=922

gender_count
#switch to percentage? df[percent] = (df['column_name'] / df['column_name'].sum()) * 100
# Out:
# Male      958
# Female    922
# Name: Sex, dtype: int64

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
#you need to study more about what functions are specifically Pandas vs pyplot vs Numpy...etc.
#you'll probably need to "know what you know" to be more successful
#OH!  it means to plot from a Pandas DataFrame

gender_df=pd.DataFrame({'Study Gender Proportions': [922, 958]},
                      index=["Female", "Male"])
plot=gender_df.plot.pie(y="Study Gender Proportions", figsize=(7,7))

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
# female=female_count
# male=male_count
labels = ["Female", "Male"]
sizes = [922, 958]
colors = ["magenta", "blue"]
explode=(0,0.1)
plt.title("Study Gender Proportions")
plt.pie(sizes, labels=labels, colors=colors, explode=explode, autopct="%1.1f%%")
plt.show()

plt.rcParams["figure.figsize"] = (7,7)

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
qob_df=clean_merge[(clean_merge["Drug Regimen"]=="Capomulin")|
                   (clean_merge["Drug Regimen"]=="Ramicane") |
                   (clean_merge["Drug Regimen"]=="Infubinol")| 
                   (clean_merge["Drug Regimen"]=="Ceftamin")]

# %%
# qob_df[["Mouse ID", "Drug Regimen", "Timepoint", "Tumor Volume (mm3)"]]
# qob_df.sort_values(['Mouse ID','Timepoint'], ascending=False).groupby('Drug Regimen').head()

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
last_entry_df=qob_df.groupby("Mouse ID").tail(1)
last_entry_df

last_entry_df.set_index("Drug Regimen").sort_index().head(20)
# Out:
#              Mouse ID     Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Capomulin        j246  Female          21          21         35
# Capomulin        v923  Female          19          21         45
# Capomulin        w150    Male          23          23         10
# Capomulin        j119  Female           7          23         45
# Capomulin        l509    Male          17          21         45
# Capomulin        r944    Male          12          25         45
# Capomulin        b128  Female           9          22         45
# Capomulin        b742    Male           7          21         45
# Capomulin        r157    Male          22          25         15
# Capomulin        l897    Male          17          19         45
# Capomulin        i557  Female           1          24         45
# Capomulin        g288    Male           3          19         45
# Capomulin        w914    Male          24          21         45
# ...

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# last_entry_merge=pd.merge(last_entry_df, clean_merge, on="Mouse ID")
# last_entry_merge
# ?????

# %%
# last_entry_df["Drug Regimen"].value_counts()
boxplot_data=last_entry_df[["Drug Regimen", "Tumor Volume (mm3)"]]

# boxplot_data.set_index("Drug Regimen")
fix_problem=boxplot_data.sort_values(by=["Drug Regimen"])

# fix_problem=fix_problem.set_index("Drug Regimen")

# %%
# Put treatments into a list for for loop (and later for plot labels)
# drugs=fix_problem["Drug Regimen"]
drugs = ["Capomulin", "Ceftamin", "Infubinol", "Ramicane"]

# # Create empty list to fill with tumor vol data (for plotting)
# tumor_volume=[]
tumor_volumes = fix_problem["Tumor Volume (mm3)"]


# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = tumor_volumes.quantile([.25,.5,.75])
lowerq=quartiles[0.25]
upperq=quartiles[0.75]
iqr=upperq-lowerq
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
# fig1, ax1=plt.subplots()
# for drug in drugs:
#     plt.figure()
#     last_entry_df.boxplot("Tumor Volume (mm3)")
plt.figure(figsize=(5,8), dpi=100)
plt.style.use('default')

capomulin=fix_problem.loc[fix_problem["Drug Regimen"] == "Capomulin"]['Tumor Volume (mm3)']
ceftamin=fix_problem.loc[fix_problem["Drug Regimen"] == "Ceftamin"]['Tumor Volume (mm3)']
infubinol=fix_problem.loc[fix_problem["Drug Regimen"] == "Infubinol"]['Tumor Volume (mm3)']
ramicane=fix_problem.loc[fix_problem["Drug Regimen"] == "Ramicane"]['Tumor Volume (mm3)']


bp=plt.boxplot([capomulin, ceftamin, infubinol,ramicane], labels=["Capomulin", "Ceftamin", "Infubinol", "Ramicane"],patch_artist=True, medianprops={'linewidth': 2})



# fix_problem.boxplot()
plt.title('Final Tumor Volumes After Treatment')
plt.ylabel("Tumor Volume")
plt.xlabel("Drug Regimen")

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
lady_mouse_df=qob_df[qob_df["Mouse ID"]=="s185"]

# %%
lady_mouse_df["Timepoint"]=lady_mouse_df["Timepoint"].astype(int)
lady_mouse_df["Tumor Volume (mm3)"]=lady_mouse_df["Tumor Volume (mm3)"].astype(int)


timepoints=lady_mouse_df["Timepoint"]
tumor_volume=lady_mouse_df["Tumor Volume (mm3)"]


x_values=timepoints
y_values=tumor_volume
plt.plot(timepoints, tumor_volume)
plt.title("Capomulin: Affect on Tumor Size for Mouse s185")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Size (mm3)")
# Out:
# C:\Users\Rachel\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Rachel\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Text(0, 0.5, 'Tumor Size (mm3)')

# %%
###gathering entries for all mice treated with Capomulin, pulling out relevant columns
capo_study=clean_merge[(clean_merge["Drug Regimen"]=="Capomulin")]
capo_study=capo_study[["Drug Regimen", "Mouse ID", "Weight (g)", "Tumor Volume (mm3)"]]
average_data=capo_study.groupby("Mouse ID").mean()
average_data.head(5)
# Out:
#           Weight (g)  Tumor Volume (mm3)
# Mouse ID
# b128              22           41.963636
# b742              21           40.083699
# f966              17           36.505973
# g288              19           41.990097
# g316              22           44.613344

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
av_tum_vol=average_data["Tumor Volume (mm3)"]
mouse_weight=average_data["Weight (g)"]


plt.scatter(mouse_weight,av_tum_vol, marker='o', facecolors='m', edgecolors='black')

plt.title("Average Tumor Size Compared to Weight for\n Mice Treated With Capomulin")

plt.xlabel("weight in (g)")
plt.ylabel("tumor size in (mm)")
# Out:
# Text(0, 0.5, 'tumor size in (mm)')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
cc=round(st.pearsonr(mouse_weight, av_tum_vol)[0],2)
print(f"Correlation Coefficient: {cc}")
# Out:
# Correlation Coefficient: 0.84

# %%
vc_slope, vc_int, vc_r, vc_p, vc_std_err = st.linregress(mouse_weight, av_tum_vol)
vc_fit = vc_slope * mouse_weight + vc_int

# %%
plt.scatter(mouse_weight,av_tum_vol, marker='o', facecolors='m', edgecolors='black')
plt.plot(mouse_weight,vc_fit,"-")

plt.title("Average Tumor Size Compared to Weight for\n Mice Treated With Capomulin")

plt.xlabel("weight in (g)")
plt.ylabel("tumor size in (mm)")
plt.show()

# %%
#THIS WAS SO MUCH FUN!
